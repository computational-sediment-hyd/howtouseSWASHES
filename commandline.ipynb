# %% [markdown]
#  - env pyswashes

# %% [markdown]
# ### case1

# %%
# !swashes 1 3 1 3 20 > sol11.dat

# %%
# !swashes 1 3 1 3 200 > sol12.dat

# %% [markdown]
# ### case2

# %%
# !swashes 1 5 1 2 200 > sol22.dat
